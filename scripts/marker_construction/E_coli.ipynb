# %% [markdown]
# # Import statements

# %%
from pathlib import Path
from helpers import *

from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

import pandas as pd

# %%
""" ============================================ DO NOT EDIT BELOW ============================================ """
""" environment variable extraction """
try:
    VARS_SET
except NameError:
    VARS_SET = True
    _cwd = %pwd
    _parent_cwd = Path(_cwd).parent
    _start_path = %env PATH
        
# %env PATH=/usr/bin:$_start_path
# Out:
# env: PATH=/usr/bin:/home/youn/mambaforge/envs/chronostrain2/bin

# %% [markdown]
# # Important global vars
#
# IMPORTANT to edit these!

# %%
gene_basedir = Path().resolve().parent.parent / "data" / "chronostrain_seeds" / "Escherichia_coli"  # the directory to store the gene files and marker index file.
refseq_metadata_description = "Escherichia coli K12 MG1655"  # This goes into the metadata of the FASTA records.
mlst_id_prefix = "E_Coli"


reference_genome_fasta = Path() / "E_Coli_Reference.fasta"
assert reference_genome_fasta.exists()

# %% [markdown]
# # Extract MLST typing genes.

# %% [markdown]
# As of 2024 Sept. 9th, E. coli has the Pasteur+Actman scheme. https://pubmlst.org/bigsdb?db=pubmlst_mlst_seqdef

# %%
paper_marker_dir = Path().resolve().parent.parent / "data" / "chronostrain_seeds" / "Escherichia_coli_custom"
paper_df = pd.read_csv(paper_marker_dir / "marker_seed_index.tsv", sep='\t', header=None)
paper_mlst_slice = paper_df.loc[paper_df[2].str.startswith("MLST")]
paper_mlst_slice
# Out:
#        0                              1                        2
# 0    adk   Escherichia_coli_1_adk.fasta  MLST:Escherichia_coli_1
# 1   fumC  Escherichia_coli_1_fumC.fasta  MLST:Escherichia_coli_1
# 2   gyrB  Escherichia_coli_1_gyrB.fasta  MLST:Escherichia_coli_1
# 3    icd   Escherichia_coli_1_icd.fasta  MLST:Escherichia_coli_1
# 4    mdh   Escherichia_coli_1_mdh.fasta  MLST:Escherichia_coli_1
# 5   purA  Escherichia_coli_1_purA.fasta  MLST:Escherichia_coli_1
# 6   recA  Escherichia_coli_1_recA.fasta  MLST:Escherichia_coli_1
# 7   dinB  Escherichia_coli_2_dinB.fasta  MLST:Escherichia_coli_2
# 8   icdA  Escherichia_coli_2_icdA.fasta  MLST:Escherichia_coli_2
# 9   pabB  Escherichia_coli_2_pabB.fasta  MLST:Escherichia_coli_2
# 10  polB  Escherichia_coli_2_polB.fasta  MLST:Escherichia_coli_2
# 11  putP  Escherichia_coli_2_putP.fasta  MLST:Escherichia_coli_2
# 12  trpA  Escherichia_coli_2_trpA.fasta  MLST:Escherichia_coli_2
# 13  trpB  Escherichia_coli_2_trpB.fasta  MLST:Escherichia_coli_2
# 14  uidA  Escherichia_coli_2_uidA.fasta  MLST:Escherichia_coli_2

# %%
import shutil

mlst_index = []
for _, row in paper_mlst_slice.iterrows():
    gene_name = row[0]
    gene_path = paper_marker_dir / row[1]
    filename = f'{gene_name}.fasta'
    shutil.copy(gene_path, gene_basedir / filename)
    mlst_index.append({'Name': f'{gene_name}', 'Fasta': filename, 'Metadata': 'MLST'})
mlst_index = pd.DataFrame(mlst_index)
display(mlst_index)
# Out:
#     Name       Fasta Metadata
# 0    adk   adk.fasta     MLST
# 1   fumC  fumC.fasta     MLST
# 2   gyrB  gyrB.fasta     MLST
# 3    icd   icd.fasta     MLST
# 4    mdh   mdh.fasta     MLST
# 5   purA  purA.fasta     MLST
# 6   recA  recA.fasta     MLST
# 7   dinB  dinB.fasta     MLST
# 8   icdA  icdA.fasta     MLST
# 9   pabB  pabB.fasta     MLST
# 10  polB  polB.fasta     MLST
# 11  putP  putP.fasta     MLST
# 12  trpA  trpA.fasta     MLST
# 13  trpB  trpB.fasta     MLST
# 14  uidA  uidA.fasta     MLST

# %% [markdown]
# # Extract MetaPhlAn markers.

# %%
taxon_label = 's__Escherichia_coli'
metaphlan_version_id = "mpa_vJun23_CHOCOPhlAnSGB_202307"
metaphlan_pkl_path = Path(f"/mnt/e/metaphlan_databases/{metaphlan_version_id}/{metaphlan_version_id}.pkl")

# %%
def extract_from_metaphlan(input_metaphlan_pkl: Path):
    parser = MetaphlanParser(input_metaphlan_pkl)

    # Extract reference seqs
    metaphlan_gene_records = []
    for marker_name, record in parser.retrieve_marker_seeds(taxon_label):
        marker_len = len(record.seq)
        print(f"Found marker `{marker_name}` (length {marker_len})")
        metaphlan_gene_records.append(record)
    return metaphlan_gene_records

# %%
metaphlan_genes = extract_from_metaphlan(metaphlan_pkl_path)
# Out:
# Searching for marker seeds from MetaPhlAn database: mpa_vJun23_CHOCOPhlAnSGB_202307.
# Target # of markers: 136
# Found marker `UniRef90_P75933|1__4|SGB10068` (length 600)
# Found marker `UniRef90_Q0T2M6|4__9|SGB10068` (length 800)
# Found marker `UniRef90_P33916|5__8|SGB10068` (length 500)
# Found marker `UniRef90_P25718|1__4|SGB10068` (length 550)
# Found marker `UniRef90_Q8XAU9|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P52614|1__4|SGB10068` (length 550)
# Found marker `UniRef90_P25798|4__8|SGB10068` (length 650)
# Found marker `UniRef90_P0AFI1|2__6|SGB10068` (length 650)
# Found marker `UniRef90_P07017|2__6|SGB10068` (length 650)
# Found marker `UniRef90_B7UQY2|3__6|SGB10068` (length 500)
# Found marker `UniRef90_P21362|1__3|SGB10068` (length 450)
# Found marker `UniRef90_Q47141|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P0ABR6|1__9|SGB10068` (length 1350)
# Found marker `UniRef90_P76254|1__5|SGB10068` (length 700)
# Found marker `UniRef90_Q8XA71|5__8|SGB10068` (length 550)
# Found marker `UniRef90_P0AEW2|1__4|SGB10068` (length 600)
# Found marker `UniRef90_P77744|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P0ABW6|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P45759|6__9|SGB10068` (length 550)
# Found marker `UniRef90_P39338|3__7|SGB10068` (length 700)
# Found marker `UniRef90_P13656|1__7|SGB10068` (length 1000)
# Found marker `UniRef90_P10805|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P31131|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P50466|2__7|SGB10068` (length 800)
# Found marker `UniRef90_P76584|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P77334|10__13|SGB10068` (length 550)
# Found marker `UniRef90_P77334|2__8|SGB10068` (length 950)
# Found marker `UniRef90_P69814|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P77256|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P30130|1__4|SGB10068` (length 550)
# Found marker `UniRef90_UPI00063D0CB9|1__8|SGB10068` (length 1150)
# Found marker `UniRef90_A0A377LLX4|1__4|SGB10068` (length 550)
# Found marker `UniRef90_P40876|1__4|SGB10068` (length 600)
# Found marker `UniRef90_P77357|1__8|SGB10068` (length 1200)
# Found marker `UniRef90_P77268|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P77416|1__9|SGB10068` (length 1350)
# Found marker `UniRef90_P76017|16__19|SGB10068` (length 550)
# Found marker `UniRef90_P76210|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P77316|1__8|SGB10068` (length 1200)
# Found marker `UniRef90_P77626|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P75937|3__6|SGB10068` (length 500)
# Found marker `UniRef90_P0AA51|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P76204|1__4|SGB10068` (length 600)
# Found marker `UniRef90_B7UNN0|3__6|SGB10068` (length 550)
# Found marker `UniRef90_Q46808|7__10|SGB10068` (length 550)
# Found marker `UniRef90_Q46814|1__4|SGB10068` (length 550)
# Found marker `UniRef90_P77294|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P0C8J9|4__8|SGB10068` (length 700)
# Found marker `UniRef90_P39381|1__7|SGB10068` (length 1050)
# Found marker `UniRef90_P76230|4__9|SGB10068` (length 850)
# Found marker `UniRef90_A0A066RI01|2__6|SGB10068` (length 650)
# Found marker `UniRef90_P0CI32|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P77329|1__6|SGB10068` (length 850)
# Found marker `UniRef90_P76052|1__9|SGB10068` (length 1350)
# Found marker `UniRef90_Q8XAY7|2__6|SGB10068` (length 650)
# Found marker `UniRef90_P45757|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P0ABD2|1__10|SGB10068` (length 1500)
# Found marker `UniRef90_P75715|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P13656|13__17|SGB10068` (length 700)
# Found marker `UniRef90_P77468|1__17|SGB10068` (length 2550)
# Found marker `UniRef90_P25960|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P75859|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P75748|1__4|SGB10068` (length 550)
# Found marker `UniRef90_P76150|1__7|SGB10068` (length 1050)
# Found marker `UniRef90_P37641|3__6|SGB10068` (length 550)
# Found marker `UniRef90_P39165|1__7|SGB10068` (length 1000)
# Found marker `UniRef90_P58203|1__5|SGB10068` (length 700)
# Found marker `UniRef90_P09348|2__5|SGB10068` (length 550)
# Found marker `UniRef90_P39267|2__5|SGB10068` (length 550)
# Found marker `UniRef90_C8U5G9|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P46139|2__8|SGB10068` (length 1000)
# Found marker `UniRef90_P0DM85|6__10|SGB10068` (length 650)
# Found marker `UniRef90_P75892|1__5|SGB10068` (length 700)
# Found marker `UniRef90_P77747|4__7|SGB10068` (length 550)
# Found marker `UniRef90_P76129|2__7|SGB10068` (length 800)
# Found marker `UniRef90_Q8XED7|10__13|SGB10068` (length 550)
# Found marker `UniRef90_P77493|2__6|SGB10068` (length 700)
# Found marker `UniRef90_P69832|6__9|SGB10068` (length 550)
# Found marker `UniRef90_P38055|3__8|SGB10068` (length 800)
# Found marker `UniRef90_P21363|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P05704|1__10|SGB10068` (length 1500)
# Found marker `UniRef90_P75906|1__5|SGB10068` (length 700)
# Found marker `UniRef90_P76251|3__7|SGB10068` (length 700)
# Found marker `UniRef90_Q320T0|6__9|SGB10068` (length 550)
# Found marker `UniRef90_P46133|2__10|SGB10068` (length 1300)
# Found marker `UniRef90_P04846|2__5|SGB10068` (length 550)
# Found marker `UniRef90_P0AEL9|1__4|SGB10068` (length 600)
# Found marker `UniRef90_P45759|1__4|SGB10068` (length 550)
# Found marker `UniRef90_P41441|1__7|SGB10068` (length 1050)
# Found marker `UniRef90_P77249|1__4|SGB10068` (length 600)
# Found marker `UniRef90_P77454|3__6|SGB10068` (length 550)
# Found marker `UniRef90_P39414|4__7|SGB10068` (length 500)
# Found marker `UniRef90_P71229|1__13|SGB10068` (length 1950)
# Found marker `UniRef90_P31436|1__4|SGB10068` (length 550)
# Found marker `UniRef90_P77437|1__10|SGB10068` (length 1500)
# Found marker `UniRef90_A0A192EQ31|1__4|SGB10068` (length 600)
# Found marker `UniRef90_J7QR22|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P77423|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P75857|9__17|SGB10068` (length 1300)
# Found marker `UniRef90_Q83R14|3__6|SGB10068` (length 500)
# Found marker `UniRef90_J7QSW1|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P77280|1__6|SGB10068` (length 900)
# Found marker `UniRef90_C6EHJ6|1__4|SGB10068` (length 600)
# Found marker `UniRef90_P77308|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P45762|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P45758|1__10|SGB10068` (length 1450)
# Found marker `UniRef90_P32140|2__8|SGB10068` (length 1000)
# Found marker `UniRef90_P77393|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P07018|1__10|SGB10068` (length 1500)
# Found marker `UniRef90_P33924|1__17|SGB10068` (length 2550)
# Found marker `UniRef90_P75858|1__7|SGB10068` (length 1050)
# Found marker `UniRef90_P38052|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P76017|7__14|SGB10068` (length 1100)
# Found marker `UniRef90_P52600|1__5|SGB10068` (length 700)
# Found marker `UniRef90_P75691|4__7|SGB10068` (length 550)
# Found marker `UniRef90_P77333|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P33340|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P77704|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P17583|1__7|SGB10068` (length 1050)
# Found marker `UniRef90_P32137|3__7|SGB10068` (length 650)
# Found marker `UniRef90_P76573|1__3|SGB10068` (length 450)
# Found marker `UniRef90_P76518|1__7|SGB10068` (length 1050)
# Found marker `UniRef90_P45756|3__9|SGB10068` (length 1000)
# Found marker `UniRef90_P39374|1__5|SGB10068` (length 750)
# Found marker `UniRef90_P32701|2__10|SGB10068` (length 1300)
# Found marker `UniRef90_P77588|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P69435|1__11|SGB10068` (length 1600)
# Found marker `UniRef90_P76773|1__4|SGB10068` (length 550)
# Found marker `UniRef90_P32136|1__8|SGB10068` (length 1150)
# Found marker `UniRef90_P77561|4__15|SGB10068` (length 1750)
# Found marker `UniRef90_P30855|17__23|SGB10068` (length 1000)
# Found marker `UniRef90_P32139|1__6|SGB10068` (length 900)
# Found marker `UniRef90_P30855|6__14|SGB10068` (length 1250)
# Found marker `UniRef90_P75908|6__9|SGB10068` (length 550)
# Found marker `UniRef90_P37627|6__9|SGB10068` (length 500)
# Found marker `UniRef90_P75908|1__4|SGB10068` (length 550)

# %%
# Write each individual MetaPhlAn gene to fasta.
metaphlan_index = []
for metaphlan_gene in metaphlan_genes:
    record = SeqRecord(
        seq=metaphlan_gene.seq,
        id=metaphlan_gene.id,
        description=f"MLST {taxon_label} marker gene version {metaphlan_version_id}"
    )

    uniref_id, middle_tag, sgb_id = metaphlan_gene.id.split("|")
    # Turn this into something posix-friendly.
    filename = f'{uniref_id}-{middle_tag}-{sgb_id}.fasta'
    with open(gene_basedir / filename, 'wt') as f:
        SeqIO.write([record], f, 'fasta')
    
    metaphlan_index.append({'Name': f'{uniref_id}-{middle_tag}-{sgb_id}', 'Fasta': filename, 'Metadata': f'MetaPhlAn:{metaphlan_version_id}'})

metaphlan_index = pd.DataFrame(metaphlan_index)

# %%
metaphlan_index
# Out:
#                                Name                                 Fasta  \
# 0     UniRef90_P75933-1__4-SGB10068   UniRef90_P75933-1__4-SGB10068.fasta
# 1     UniRef90_Q0T2M6-4__9-SGB10068   UniRef90_Q0T2M6-4__9-SGB10068.fasta
# 2     UniRef90_P33916-5__8-SGB10068   UniRef90_P33916-5__8-SGB10068.fasta
# 3     UniRef90_P25718-1__4-SGB10068   UniRef90_P25718-1__4-SGB10068.fasta
# 4     UniRef90_Q8XAU9-1__3-SGB10068   UniRef90_Q8XAU9-1__3-SGB10068.fasta
# ..                              ...                                   ...
# 131   UniRef90_P32139-1__6-SGB10068   UniRef90_P32139-1__6-SGB10068.fasta
# 132  UniRef90_P30855-6__14-SGB10068  UniRef90_P30855-6__14-SGB10068.fasta
# 133   UniRef90_P75908-6__9-SGB10068   UniRef90_P75908-6__9-SGB10068.fasta
# 134   UniRef90_P37627-6__9-SGB10068   UniRef90_P37627-6__9-SGB10068.fasta
# 135   UniRef90_P75908-1__4-SGB10068   UniRef90_P75908-1__4-SGB10068.fasta
#
#                                       Metadata
# 0    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 1    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 2    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 3    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 4    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# ..                                         ...
# 131  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 132  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 133  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 134  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 135  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
#
# [136 rows x 3 columns]

# %% [markdown]
# # Write the index files.

# %%
concat_index = pd.concat([mlst_index, metaphlan_index])
concat_index.to_csv(gene_basedir / "marker_seed_index.tsv", sep='\t', index=False, header=False)
