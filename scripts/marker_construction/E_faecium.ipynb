# %% [markdown]
# # Import statements

# %%
from pathlib import Path
from helpers import *

from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

import pandas as pd

# %%
""" ============================================ DO NOT EDIT BELOW ============================================ """
""" environment variable extraction """
try:
    VARS_SET
except NameError:
    VARS_SET = True
    _cwd = %pwd
    _parent_cwd = Path(_cwd).parent
    _start_path = %env PATH
        
# %env PATH=/usr/bin:$_start_path
# Out:
# env: PATH=/usr/bin:/home/youn/mambaforge/envs/chronostrain2/bin

# %% [markdown]
# # Important global vars
#
# IMPORTANT to edit these!

# %%
gene_basedir = Path().resolve().parent.parent / "data" / "chronostrain_seeds" / "Enterococcus_faecium"  # the directory to store the gene files and marker index file.
refseq_metadata_description = "Enterococcus faecium SRR24"  # This goes into the metadata of the FASTA records.
mlst_id_prefix = "E_Faecium"


reference_genome_fasta = Path() / "E_Faecium_Reference.fasta"
assert reference_genome_fasta.exists()

# %% [markdown]
# # Extract MLST typing genes.

# %% [markdown]
# ## Enterococcus faecium MLST genes
#
# To save some time/ambiguity (the MLST website has hundreds of sites but the official XML schema only lists 7 genes), we'll use the pre-generated FASTA file from the MLST official locus schema file.

# %%
mlst_fasta = Path() / "E_Faecium_Schema_MLST.fasta"
mlst_index = []

for record in SeqIO.parse(mlst_fasta, "fasta"):
    filename = f'{record.id}.fasta'
    with open(gene_basedir / filename, 'wt') as f:
        SeqIO.write([record], f, 'fasta')
    
    mlst_index.append({'Name': f'{record.id}', 'Fasta': filename, 'Metadata': 'MLST'})
mlst_index = pd.DataFrame(mlst_index)

# %%
display(mlst_index)
# Out:
#    Name       Fasta Metadata
# 0   adk   adk.fasta     MLST
# 1  atpA  atpA.fasta     MLST
# 2   ddl   ddl.fasta     MLST
# 3   gdh   gdh.fasta     MLST
# 4   gyd   gyd.fasta     MLST
# 5  pstS  pstS.fasta     MLST
# 6  purK  purK.fasta     MLST

# %% [markdown]
# # Extract MetaPhlAn markers.

# %%
taxon_label = 's__Enterococcus_faecium'
metaphlan_version_id = "mpa_vJun23_CHOCOPhlAnSGB_202307"
metaphlan_pkl_path = Path(f"/mnt/e/metaphlan_databases/{metaphlan_version_id}/{metaphlan_version_id}.pkl")

# %%
def extract_from_metaphlan(input_metaphlan_pkl: Path):
    parser = MetaphlanParser(input_metaphlan_pkl)

    # Extract reference seqs
    metaphlan_gene_records = []
    for marker_name, record in parser.retrieve_marker_seeds(taxon_label):
        marker_len = len(record.seq)
        print(f"Found marker `{marker_name}` (length {marker_len})")
        metaphlan_gene_records.append(record)
    return metaphlan_gene_records

# %%
metaphlan_genes = extract_from_metaphlan(metaphlan_pkl_path)
# Out:
# Searching for marker seeds from MetaPhlAn database: mpa_vJun23_CHOCOPhlAnSGB_202307.
# Target # of markers: 166
# Found marker `UniRef90_S4DR35|1__4|SGB7967` (length 550)
# Found marker `UniRef90_A0A132PAA3|1__3|SGB7967` (length 450)
# Found marker `UniRef90_A0A132Z5H9|1__7|SGB7967` (length 1050)
# Found marker `UniRef90_A0A132Z370|8__13|SGB7967` (length 800)
# Found marker `UniRef90_A0A449FVC2|3__6|SGB7967` (length 500)
# Found marker `UniRef90_A0A132P5M5|1__5|SGB7967` (length 700)
# Found marker `UniRef90_A0A132Z5C0|1__5|SGB7967` (length 700)
# Found marker `UniRef90_A0A133MT97|3__6|SGB7967` (length 500)
# Found marker `UniRef90_A0A132Z349|1__4|SGB7967` (length 550)
# Found marker `UniRef90_A0A449F934|1__7|SGB7967` (length 1050)
# Found marker `UniRef90_A0A286V0J6|2__5|SGB7967` (length 500)
# Found marker `UniRef90_A0A133CH55|1__3|SGB7967` (length 450)
# Found marker `UniRef90_S4F8R3|1__12|SGB7967` (length 1750)
# Found marker `UniRef90_UPI0008A587DC|4__7|SGB7967` (length 500)
# Found marker `UniRef90_A0A132Z1X2|1__7|SGB7967` (length 1050)
# Found marker `UniRef90_A0A132Z268|1__5|SGB7967` (length 750)
# Found marker `UniRef90_A0A132Z201|1__8|SGB7967` (length 1200)
# Found marker `UniRef90_A0A0M1X9W8|1__7|SGB7967` (length 1050)
# Found marker `UniRef90_A0A132Z3K9|1__6|SGB7967` (length 900)
# Found marker `UniRef90_R2MC49|1__12|SGB7967` (length 1800)
# Found marker `UniRef90_A0A1A7SYV5|1__6|SGB7967` (length 900)
# Found marker `UniRef90_A0A1V2U9Y2|1__4|SGB7967` (length 600)
# Found marker `UniRef90_A0A0M2AM03|4__9|SGB7967` (length 850)
# Found marker `UniRef90_A0A0M1X639|5__8|SGB7967` (length 550)
# Found marker `UniRef90_A0A1M2WMI7|1__3|SGB7967` (length 450)
# Found marker `UniRef90_A0A449FRQ6|1__12|SGB7967` (length 1800)
# Found marker `UniRef90_A0A132Z666|1__9|SGB7967` (length 1350)
# Found marker `UniRef90_S4EHJ5|1__10|SGB7967` (length 1500)
# Found marker `UniRef90_A0A132Z6Z6|1__11|SGB7967` (length 1650)
# Found marker `UniRef90_S4DTH8|1__11|SGB7967` (length 1650)
# Found marker `UniRef90_A0A449FSK3|1__4|SGB7967` (length 600)
# Found marker `UniRef90_A0A132Z584|8__11|SGB7967` (length 500)
# Found marker `UniRef90_A0A449EMI1|1__5|SGB7967` (length 750)
# Found marker `UniRef90_A0A449FAV5|1__3|SGB7967` (length 450)
# Found marker `UniRef90_A0A132Z0C3|1__8|SGB7967` (length 1200)
# Found marker `UniRef90_A0A449FAX0|1__8|SGB7967` (length 1200)
# Found marker `UniRef90_A0A449DE14|1__9|SGB7967` (length 1350)
# Found marker `UniRef90_A0A1L8SFW0|2__6|SGB7967` (length 700)
# Found marker `UniRef90_A0A132Z584|14__20|SGB7967` (length 950)
# Found marker `UniRef90_A0A0M2B5D6|1__4|SGB7967` (length 550)
# Found marker `UniRef90_C9BZK1|1__4|SGB7967` (length 600)
# Found marker `UniRef90_A0A133CNK5|1__5|SGB7967` (length 750)
# Found marker `UniRef90_Q9X561|1__4|SGB7967` (length 600)
# Found marker `UniRef90_A0A132YYS8|1__3|SGB7967` (length 450)
# Found marker `UniRef90_A0A132P9C9|1__6|SGB7967` (length 900)
# Found marker `UniRef90_A0A0M2APG1|1__4|SGB7967` (length 550)
# Found marker `UniRef90_A0A133CN99|1__3|SGB7967` (length 450)
# Found marker `UniRef90_I3U0U7|1__9|SGB7967` (length 1350)
# Found marker `UniRef90_E3USM7|2__5|SGB7967` (length 550)
# Found marker `UniRef90_A0A449EKF3|1__5|SGB7967` (length 750)
# Found marker `UniRef90_A0A132ZFH8|1__3|SGB7967` (length 450)
# Found marker `UniRef90_J8WM75|1__18|SGB7968` (length 2700)
# Found marker `UniRef90_A0A133MSM0|1__3|SGB7968` (length 450)
# Found marker `UniRef90_J7CT77|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A133MXB3|1__3|SGB7968` (length 450)
# Found marker `UniRef90_A0A179ETG1|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A133N7L1|1__3|SGB7968` (length 450)
# Found marker `UniRef90_A0A132PAA3|1__3|SGB7968` (length 450)
# Found marker `UniRef90_UPI000F513FC1|1__5|SGB7968` (length 700)
# Found marker `UniRef90_J8Z5W4|1__6|SGB7968` (length 900)
# Found marker `UniRef90_J7CT94|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A133MP96|1__3|SGB7968` (length 450)
# Found marker `UniRef90_L2LAZ2|1__6|SGB7968` (length 900)
# Found marker `UniRef90_J6Y662|1__4|SGB7968` (length 600)
# Found marker `UniRef90_UPI000F61B5F1|1__5|SGB7968` (length 700)
# Found marker `UniRef90_A0A133MTW9|1__3|SGB7968` (length 450)
# Found marker `UniRef90_J6JVD8|1__5|SGB7968` (length 750)
# Found marker `UniRef90_J8ZGM4|1__11|SGB7968` (length 1650)
# Found marker `UniRef90_J7CWE5|1__5|SGB7968` (length 700)
# Found marker `UniRef90_A0A1A7S1L2|12__15|SGB7968` (length 550)
# Found marker `UniRef90_A0A133MTV3|2__5|SGB7968` (length 550)
# Found marker `UniRef90_A0A2A7T0T8|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A449FVC2|3__6|SGB7968` (length 500)
# Found marker `UniRef90_R2PFM9|1__3|SGB7968` (length 450)
# Found marker `UniRef90_R2Q4B8|1__4|SGB7968` (length 550)
# Found marker `UniRef90_A0A133N5V6|5__10|SGB7968` (length 800)
# Found marker `UniRef90_A0A133MTH7|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A133MNR1|1__3|SGB7968` (length 450)
# Found marker `UniRef90_J8WPY5|4__9|SGB7968` (length 850)
# Found marker `UniRef90_J7CV36|1__5|SGB7968` (length 750)
# Found marker `UniRef90_J8ZVT7|1__13|SGB7968` (length 1950)
# Found marker `UniRef90_J6Y6E7|1__5|SGB7968` (length 750)
# Found marker `UniRef90_R2MBR8|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A449FUL6|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A2C6EQG7|1__9|SGB7968` (length 1350)
# Found marker `UniRef90_J8VRG8|1__4|SGB7968` (length 600)
# Found marker `UniRef90_J9A670|1__3|SGB7968` (length 450)
# Found marker `UniRef90_A0A3N3MKP5|1__4|SGB7968` (length 550)
# Found marker `UniRef90_A0A133MYB9|1__4|SGB7968` (length 600)
# Found marker `UniRef90_J7CWV2|1__14|SGB7968` (length 2100)
# Found marker `UniRef90_J8VPR1|1__3|SGB7968` (length 450)
# Found marker `UniRef90_J8W3S4|1__10|SGB7968` (length 1500)
# Found marker `UniRef90_J8YXN2|1__8|SGB7968` (length 1200)
# Found marker `UniRef90_A0A3F3JU71|1__12|SGB7968` (length 1800)
# Found marker `UniRef90_A0A133MNV1|1__3|SGB7968` (length 450)
# Found marker `UniRef90_A0A133MZF8|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A133MSM4|2__5|SGB7968` (length 550)
# Found marker `UniRef90_A0A133MZH9|1__10|SGB7968` (length 1500)
# Found marker `UniRef90_A0A410PE65|1__6|SGB7968` (length 900)
# Found marker `UniRef90_A0A133MSL7|1__8|SGB7968` (length 1200)
# Found marker `UniRef90_A0A449FUJ9|1__18|SGB7968` (length 2700)
# Found marker `UniRef90_A0A133MYB8|1__9|SGB7968` (length 1350)
# Found marker `UniRef90_J8WGC7|4__7|SGB7968` (length 500)
# Found marker `UniRef90_A0A133MMB5|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A133MW34|1__13|SGB7968` (length 1950)
# Found marker `UniRef90_C9AN70|1__8|SGB7968` (length 1200)
# Found marker `UniRef90_A0A133MXD9|1__18|SGB7968` (length 2700)
# Found marker `UniRef90_A0A242BI95|1__10|SGB7968` (length 1500)
# Found marker `UniRef90_J6YS35|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A133MXA7|1__6|SGB7968` (length 900)
# Found marker `UniRef90_A0A2V2L9L3|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A133MXC9|1__8|SGB7968` (length 1200)
# Found marker `UniRef90_A0A133N6L5|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A1L8TJB4|1__3|SGB7968` (length 450)
# Found marker `UniRef90_C9APF9|1__5|SGB7968` (length 750)
# Found marker `UniRef90_J6Y9B9|1__11|SGB7968` (length 1650)
# Found marker `UniRef90_C9ASM9|1__3|SGB7968` (length 450)
# Found marker `UniRef90_A0A377KKB0|2__5|SGB7968` (length 500)
# Found marker `UniRef90_C9ANM2|1__10|SGB7968` (length 1500)
# Found marker `UniRef90_A0A133N7I4|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A2V2PG56|1__3|SGB7968` (length 450)
# Found marker `UniRef90_J8ZME3|1__10|SGB7968` (length 1500)
# Found marker `UniRef90_A0A133N1X4|1__3|SGB7968` (length 450)
# Found marker `UniRef90_A0A133MRZ0|2__5|SGB7968` (length 500)
# Found marker `UniRef90_A0A133MWQ8|1__4|SGB7968` (length 600)
# Found marker `UniRef90_A0A132Z3C4|2__5|SGB7968` (length 550)
# Found marker `UniRef90_J8YJG1|1__7|SGB7968` (length 1050)
# Found marker `UniRef90_A0A132Z370|8__13|SGB7968` (length 800)
# Found marker `UniClust90_ADKOOCNG00044|1__7|SGB7968` (length 1050)
# Found marker `UniRef90_A0A133N5F6|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A133MWQ4|1__11|SGB7968` (length 1650)
# Found marker `UniRef90_A0A133MT97|2__6|SGB7968` (length 650)
# Found marker `UniRef90_J7CT71|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A133MTV4|2__10|SGB7968` (length 1300)
# Found marker `UniRef90_A0A3N3L6I7|1__6|SGB7968` (length 850)
# Found marker `UniRef90_L2LEU4|1__6|SGB7968` (length 900)
# Found marker `UniRef90_L2LB95|1__6|SGB7968` (length 900)
# Found marker `UniRef90_A0A449FQV9|1__7|SGB7968` (length 1050)
# Found marker `UniRef90_A0A449FR37|1__6|SGB7968` (length 900)
# Found marker `UniRef90_A0A3N3L536|1__4|SGB7968` (length 600)
# Found marker `UniRef90_V5XMG7|1__8|SGB7968` (length 1200)
# Found marker `UniRef90_R2PDX4|1__13|SGB7968` (length 1950)
# Found marker `UniRef90_A0A449FQV4|1__9|SGB7968` (length 1350)
# Found marker `UniRef90_A0A377L6A9|1__9|SGB7968` (length 1350)
# Found marker `UniRef90_L2LA75|1__11|SGB7968` (length 1650)
# Found marker `UniRef90_A0A133MT81|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A3F3NSV2|3__9|SGB7968` (length 1000)
# Found marker `UniRef90_R2PJR1|10__13|SGB7968` (length 550)
# Found marker `UniRef90_A0A133MSF6|19__26|SGB7968` (length 1100)
# Found marker `UniRef90_A0A133MSF6|9__14|SGB7968` (length 800)
# Found marker `UniRef90_J8WNM8|1__15|SGB7968` (length 2250)
# Found marker `UniRef90_J6Y1N8|1__10|SGB7968` (length 1500)
# Found marker `UniRef90_J8YLG5|2__5|SGB7968` (length 500)
# Found marker `UniRef90_A0A132PA94|3__6|SGB7968` (length 500)
# Found marker `UniRef90_C9AS43|1__7|SGB7968` (length 1050)
# Found marker `UniRef90_S4E7C2|1__6|SGB7968` (length 850)
# Found marker `UniRef90_J8W7C1|1__6|SGB7968` (length 900)
# Found marker `UniRef90_A0A133MWR8|1__7|SGB7968` (length 1050)
# Found marker `UniRef90_A0A449FUM9|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A449FUY0|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A2A7SYF1|1__6|SGB7968` (length 900)
# Found marker `UniRef90_A0A133N557|1__7|SGB7968` (length 1050)
# Found marker `UniRef90_J8ZGM0|2__9|SGB7968` (length 1150)
# Found marker `UniRef90_A0A133MTM1|4__7|SGB7968` (length 500)
# Found marker `UniRef90_A0A2A7SXH8|1__5|SGB7968` (length 750)
# Found marker `UniRef90_A0A133MNT3|1__3|SGB7968` (length 450)

# %%
# Write each individual MetaPhlAn gene to fasta.
metaphlan_index = []
for metaphlan_gene in metaphlan_genes:
    record = SeqRecord(
        seq=metaphlan_gene.seq,
        id=metaphlan_gene.id,
        description=f"MLST {taxon_label} marker gene version {metaphlan_version_id}"
    )

    uniref_id, middle_tag, sgb_id = metaphlan_gene.id.split("|")
    # Turn this into something posix-friendly.
    filename = f'{uniref_id}-{middle_tag}-{sgb_id}.fasta'
    with open(gene_basedir / filename, 'wt') as f:
        SeqIO.write([record], f, 'fasta')
    
    metaphlan_index.append({'Name': f'{uniref_id}-{middle_tag}-{sgb_id}', 'Fasta': filename, 'Metadata': f'MetaPhlAn:{metaphlan_version_id}'})

metaphlan_index = pd.DataFrame(metaphlan_index)

# %%
metaphlan_index
# Out:
#                                   Name  \
# 0         UniRef90_S4DR35-1__4-SGB7967
# 1     UniRef90_A0A132PAA3-1__3-SGB7967
# 2     UniRef90_A0A132Z5H9-1__7-SGB7967
# 3    UniRef90_A0A132Z370-8__13-SGB7967
# 4     UniRef90_A0A449FVC2-3__6-SGB7967
# ..                                 ...
# 161   UniRef90_A0A133N557-1__7-SGB7968
# 162       UniRef90_J8ZGM0-2__9-SGB7968
# 163   UniRef90_A0A133MTM1-4__7-SGB7968
# 164   UniRef90_A0A2A7SXH8-1__5-SGB7968
# 165   UniRef90_A0A133MNT3-1__3-SGB7968
#
#                                        Fasta  \
# 0         UniRef90_S4DR35-1__4-SGB7967.fasta
# 1     UniRef90_A0A132PAA3-1__3-SGB7967.fasta
# 2     UniRef90_A0A132Z5H9-1__7-SGB7967.fasta
# 3    UniRef90_A0A132Z370-8__13-SGB7967.fasta
# 4     UniRef90_A0A449FVC2-3__6-SGB7967.fasta
# ..                                       ...
# 161   UniRef90_A0A133N557-1__7-SGB7968.fasta
# 162       UniRef90_J8ZGM0-2__9-SGB7968.fasta
# 163   UniRef90_A0A133MTM1-4__7-SGB7968.fasta
# 164   UniRef90_A0A2A7SXH8-1__5-SGB7968.fasta
# 165   UniRef90_A0A133MNT3-1__3-SGB7968.fasta
#
#                                       Metadata
# 0    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 1    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 2    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 3    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 4    MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# ..                                         ...
# 161  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 162  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 163  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 164  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
# 165  MetaPhlAn:mpa_vJun23_CHOCOPhlAnSGB_202307
#
# [166 rows x 3 columns]

# %% [markdown]
# # Write the index files.

# %%
concat_index = pd.concat([mlst_index, metaphlan_index])
concat_index.to_csv(gene_basedir / "marker_seed_index.tsv", sep='\t', index=False, header=False)
